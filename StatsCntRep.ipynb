# %%
# Import libraries as required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)

# Load in the data set
df = pd.read_csv('./ResultsCntRep.csv')
df
# Out:
#     Test    State Correct?  Time(ms)
# 0      2  success     True   974.780
# 1     10  success    False  1679.898
# 2     19  success    False  2374.422
# 3     22  success     True  1748.843
# 4     28  success    False  4881.311
# 5     58  success    False  5882.911
# 6     60  failure      NaN       NaN
# 7     63  success    False  3219.399
# 8     72  success    False  2397.823
# 9     90  success     True  2148.970
# 10   120  success    False  2027.463
# 11   127  success    False  2272.254
# 12   131  success    False  3789.186
# 13   135  success    False  1487.873
# 14   148  success    False  5509.899
# 15   149  success     True  2397.421
# 16   157  success     True  2960.655
# 17   164  success    False  2108.972
# 18   171  success    False  3933.415
# 19   176  success     True  1990.681
# 20   185  success     True  6656.926
# 21   186  success    False  4846.636
# 22   191  success    False  4405.787
# 23   196  success     True  3678.086
# 24   203  success    False  2171.044
# 25   211  success    False  4631.547
# 26   214  success    False  3745.703
# 27   219  success     True  3648.894
# 28   229  success     True  7007.574
# 29   234  success     True  6424.737
# 30   237  success     True  4801.444
# 31   239  success    False  3983.293
# 32   240  success    False  5545.356
# 33   251  success    False  4132.801
# 34   254  success     True  4875.472
# 35   256  success     True  7092.164

# %%
#len(df[df['Correct?']==True])

# %%
labels= ['False', 'True', 'NaN']
colors=['blue', 'orange', 'green']
df["Correct?"].value_counts(normalize=True).plot.pie(labels=labels, colors=colors, startangle=90, autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Correct?'>

# %%
fig = plt.figure(figsize=(20,10))
# Calculate the simple average of the data
x=df['Test']
y=df['Time(ms)']/1000
y_mean = [np.mean(y)]*len(x)
ax = fig.add_subplot()
ax.plot(x, y, color='blue')
ax.plot(x, y_mean, color='green')
ax.legend(['Data', 'Mean'])
ax.set_xlabel("Test number")
ax.set_ylabel("Solving time(s)")
ax.set_title("Tests line chart (mean time: %.2f seconds)"%np.mean(y))
# Out:
# Text(0.5, 1.0, 'Tests line chart (mean time: 3.76 seconds)')
